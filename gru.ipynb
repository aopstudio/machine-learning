# %%
import torch
from torch import nn
from d2l import torch as d2l

batch_size, num_steps = 32,35
train_iter, vocab = d2l.load_data_time_machine(batch_size,num_steps)
num_hiddens = 256
num_epochs,lr = 500,1
vocab_size = len(vocab)
device = d2l.try_gpu()
num_inputs = vocab_size
gru_layer = nn.GRU(num_inputs,num_hiddens)
model = d2l.RNNModel(gru_layer, len(vocab))
model = model.to(device)
d2l.train_ch8(model,train_iter,vocab,lr,num_epochs,device)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/cenzhedong/Documents/GitHub/machine-learning/gru.ipynb Cell 1' in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/cenzhedong/Documents/GitHub/machine-learning/gru.ipynb#ch0000000?line=12'>13</a> model = d2l.RNNModel(gru_layer, len(vocab))
#      <a href='vscode-notebook-cell:/Users/cenzhedong/Documents/GitHub/machine-learning/gru.ipynb#ch0000000?line=13'>14</a> model = model.to(device)
# ---> <a href='vscode-notebook-cell:/Users/cenzhedong/Documents/GitHub/machine-learning/gru.ipynb#ch0000000?line=14'>15</a> d2l.train_ch8(model,train_iter,vocab,lr,num_epochs,device)
#
# File ~/opt/anaconda3/envs/torch_nightly_env/lib/python3.8/site-packages/d2l/torch.py:798, in train_ch8(net, train_iter, vocab, lr, num_epochs, device, use_random_iter)
#     796 # Train and predict
#     797 for epoch in range(num_epochs):
# --> 798     ppl, speed = train_epoch_ch8(
#     799         net, train_iter, loss, updater, device, use_random_iter)
#     800     if (epoch + 1) % 10 == 0:
#     801         print(predict('time traveller'))
#
# File ~/opt/anaconda3/envs/torch_nightly_env/lib/python3.8/site-packages/d2l/torch.py:767, in train_epoch_ch8(net, train_iter, loss, updater, device, use_random_iter)
#     765 y = Y.T.reshape(-1)
#     766 X, y = X.to(device), y.to(device)
# --> 767 y_hat, state = net(X, state)
#     768 l = loss(y_hat, y.long()).mean()
#     769 if isinstance(updater, torch.optim.Optimizer):
#
# File ~/opt/anaconda3/envs/torch_nightly_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1186, in Module._call_impl(self, *input, **kwargs)
#    1182 # If we don't have any hooks, we want to skip the rest of the logic in
#    1183 # this function, and just call forward.
#    1184 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1185         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1186     return forward_call(*input, **kwargs)
#    1187 # Do not call functions when jit is used
#    1188 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch_nightly_env/lib/python3.8/site-packages/d2l/torch.py:828, in RNNModel.forward(self, inputs, state)
#     826 X = F.one_hot(inputs.T.long(), self.vocab_size)
#     827 X = X.to(torch.float32)
# --> 828 Y, state = self.rnn(X, state)
#     829 # The fully connected layer will first change the shape of `Y` to
#     830 # (`num_steps` * `batch_size`, `num_hiddens`). Its output shape is
#     831 # (`num_steps` * `batch_size`, `vocab_size`).
#     832 output = self.linear(Y.reshape((-1, Y.shape[-1])))
#
# File ~/opt/anaconda3/envs/torch_nightly_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1186, in Module._call_impl(self, *input, **kwargs)
#    1182 # If we don't have any hooks, we want to skip the rest of the logic in
#    1183 # this function, and just call forward.
#    1184 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1185         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1186     return forward_call(*input, **kwargs)
#    1187 # Do not call functions when jit is used
#    1188 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch_nightly_env/lib/python3.8/site-packages/torch/nn/modules/rnn.py:955, in GRU.forward(self, input, hx)
#     953 self.check_forward_args(input, hx, batch_sizes)
#     954 if batch_sizes is None:
# --> 955     result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#     956                      self.dropout, self.training, self.bidirectional, self.batch_first)
#     957 else:
#     958     result = _VF.gru(input, batch_sizes, hx, self._flat_weights, self.bias,
#     959                      self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:
